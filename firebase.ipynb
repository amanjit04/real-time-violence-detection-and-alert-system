# %%
# !pip install telepot
# !pip install geocoder
import numpy as np
import cv2
from keras.models import load_model
from collections import deque
import telepot
import time
import geocoder
import socket
def get_current_location():
    # Get current location
    location = geocoder.ip('me')
    location_info = f"LOCATION: {location.city}, {location.state}, {location.country}\n"
    return location_info

def print_results(video):
    # Initializing variables
    trueCount = 0
    imageSaved = 0
    filename = 'savedImage.jpg'
    video_filename = 'recordedVideo.avi'
    sendAlert = 0

    # Get current location
    location_info = get_current_location()

    # Loading pre-trained Keras model
    print("Loading model ...")
    model = load_model('./modelnew.h5')
    Q = deque(maxlen=128)

    # Capturing video
    vs = cv2.VideoCapture(video)
    writer = None
    (W, H) = (None, None)
    count = 0
    
    # Looping through video frames
    while True:
        (grabbed, frame) = vs.read()

        if not grabbed:
            break

        if W is None or H is None:
            (H, W) = frame.shape[:2]

        output = frame.copy()

        # Preprocessing frame for model input
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        frame = cv2.resize(frame, (128, 128)).astype("float32")
        frame = frame.reshape(128, 128, 3) / 255

        # Predicting violence probability
        preds = model.predict(np.expand_dims(frame, axis=0))[0]
        Q.append(preds)

        # Calculating average prediction
        results = np.array(Q).mean(axis=0)
        i = (preds > 0.50)[0]  # Thresholding predictions
        label = i

        # Determining text color based on violence label
        text_color = (0, 255, 0)  # default: green
        if label:  # Violence prob
            text_color = (0, 0, 255)  # red
            trueCount += 1

        # Adding text to the output frame
        text = "Violence: {}".format(label)
        FONT = cv2.FONT_HERSHEY_SIMPLEX
        cv2.putText(output, text, (35, 50), FONT, 1.25, text_color, 3)

        # Initializing video writer if not done
        if writer is None:
            fourcc = cv2.VideoWriter_fourcc(*"MJPG")
            writer = cv2.VideoWriter(video_filename, fourcc, 30, (W, H), True)

        # Writing frame to output video
        writer.write(output)

        # Displaying output frame
        cv2.imshow("Output", output)

        # Saving image and sending alert if violence detected for 50 consecutive frames
        if trueCount == 50:
            if imageSaved == 0:
                if label:
                    cv2.imwrite(filename, output)  # Save the frame
                    imageSaved = 1

            if sendAlert == 0:
                timeMoment = time.strftime("%H:%M:%S \nDate %d-%m-%y")
                bot = telepot.Bot('7186069023:AAFg_KT_mSUd5ofySXlwViyK4k32Gu3ahnU')
                bot.sendMessage(-1001991802221, f"VIOLENCE ALERT!!\n{location_info}TIME: {timeMoment}")
                with open(video_filename, 'rb') as video_file:
                    bot.sendVideo(-1001991802221, video_file)
                bot.sendPhoto(-1001991802221, photo=open(filename, 'rb'))
                sendAlert = 1

        # Checking for key press to quit
        key = cv2.waitKey(1) & 0xFF
        if key == ord("q"):
            break

    # Cleaning up
    print("[INFO] cleaning up...")
    writer.release()
    vs.release()
    #violence
V_path = "./New Dataset/Fight-20240507T205137Z-001/Fight/F2.4.mp4"
print_results(V_path)
# Out:
# Requirement already satisfied: telepot in c:\users\manjit kumar\appdata\local\programs\python\python312\lib\site-packages (12.7)
# Requirement already satisfied: urllib3>=1.9.1 in c:\users\manjit kumar\appdata\local\programs\python\python312\lib\site-packages (from telepot) (1.26.18)
# Requirement already satisfied: aiohttp>=3.0.0 in c:\users\manjit kumar\appdata\local\programs\python\python312\lib\site-packages (from telepot) (3.9.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\manjit kumar\appdata\local\programs\python\python312\lib\site-packages (from aiohttp>=3.0.0->telepot) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\manjit kumar\appdata\local\programs\python\python312\lib\site-packages (from aiohttp>=3.0.0->telepot) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\manjit kumar\appdata\local\programs\python\python312\lib\site-packages (from aiohttp>=3.0.0->telepot) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\manjit kumar\appdata\local\programs\python\python312\lib\site-packages (from aiohttp>=3.0.0->telepot) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\manjit kumar\appdata\local\programs\python\python312\lib\site-packages (from aiohttp>=3.0.0->telepot) (1.9.4)
# Requirement already satisfied: idna>=2.0 in c:\users\manjit kumar\appdata\local\programs\python\python312\lib\site-packages (from yarl<2.0,>=1.0->aiohttp>=3.0.0->telepot) (3.6)
# Requirement already satisfied: geocoder in c:\users\manjit kumar\appdata\local\programs\python\python312\lib\site-packages (1.38.1)
# Requirement already satisfied: click in c:\users\manjit kumar\appdata\local\programs\python\python312\lib\site-packages (from geocoder) (8.1.7)
# Requirement already satisfied: future in c:\users\manjit kumar\appdata\local\programs\python\python312\lib\site-packages (from geocoder) (1.0.0)
# Requirement already satisfied: ratelim in c:\users\manjit kumar\appdata\local\programs\python\python312\lib\site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: requests in c:\users\manjit kumar\appdata\local\programs\python\python312\lib\site-packages (from geocoder) (2.31.0)
# Requirement already satisfied: six in c:\users\manjit kumar\appdata\local\programs\python\python312\lib\site-packages (from geocoder) (1.16.0)
# Requirement already satisfied: colorama in c:\users\manjit kumar\appdata\local\programs\python\python312\lib\site-packages (from click->geocoder) (0.4.6)
# Requirement already satisfied: decorator in c:\users\manjit kumar\appdata\local\programs\python\python312\lib\site-packages (from ratelim->geocoder) (5.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\manjit kumar\appdata\local\programs\python\python312\lib\site-packages (from requests->geocoder) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\manjit kumar\appdata\local\programs\python\python312\lib\site-packages (from requests->geocoder) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\manjit kumar\appdata\local\programs\python\python312\lib\site-packages (from requests->geocoder) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\manjit kumar\appdata\local\programs\python\python312\lib\site-packages (from requests->geocoder) (2024.2.2)
# Loading model ...
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=None, read=None, redirect=0, status=None)) after connection broken by 'SSLError(SSLEOFError(8, 'EOF occurred in violation of protocol (_ssl.c:2406)'))': /bot7186069023:AAFg_KT_mSUd5ofySXlwViyK4k32Gu3ahnU/sendVideo
# ---------------------------------------------------------------------------
# TelegramError                             Traceback (most recent call last)
# Cell In[2], line 114
#     112     #violence
#     113 V_path = "./New Dataset/Fight-20240507T205137Z-001/Fight/F2.4.mp4"
# --> 114 print_results(V_path)
#
# Cell In[2], line 99, in print_results(video)
#      97 bot.sendMessage(-1001991802221, f"VIOLENCE ALERT!!\n{location_info}TIME: {timeMoment}")
#      98 with open(video_filename, 'rb') as video_file:
# ---> 99     bot.sendVideo(-1001991802221, video_file)
#     100 bot.sendPhoto(-1001991802221, photo=open(filename, 'rb'))
#     101 sendAlert = 1
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\telepot\__init__.py:588, in Bot.sendVideo(self, chat_id, video, duration, width, height, caption, parse_mode, supports_streaming, disable_notification, reply_to_message_id, reply_markup)
#     582 """
#     583 See: https://core.telegram.org/bots/api#sendvideo
#     584
#     585 :param video: Same as ``photo`` in :meth:`telepot.Bot.sendPhoto`
#     586 """
#     587 p = _strip(locals(), more=['video'])
# --> 588 return self._api_request_with_file('sendVideo', _rectify(p), 'video', video)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\telepot\__init__.py:499, in Bot._api_request_with_file(self, method, params, file_key, file_value, **kwargs)
#     497 else:
#     498     files = {file_key: file_value}
# --> 499     return self._api_request(method, _rectify(params), files, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\telepot\__init__.py:491, in Bot._api_request(self, method, params, files, **kwargs)
#     490 def _api_request(self, method, params=None, files=None, **kwargs):
# --> 491     return api.request((self._token, method, params, files), **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\telepot\api.py:155, in request(req, **user_kw)
#     153 fn, args, kwargs = _transform(req, **user_kw)
#     154 r = fn(*args, **kwargs)  # `fn` must be thread-safe
# --> 155 return _parse(r)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\telepot\api.py:150, in _parse(response)
#     147         raise e(description, error_code, data)
#     149 # ... or raise generic error
# --> 150 raise exception.TelegramError(description, error_code, data)
#
# TelegramError: ('Request Entity Too Large', 413, {'ok': False, 'error_code': 413, 'description': 'Request Entity Too Large'})
